# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\SIDDHARTH\\Downloads\\crop recommendation system\\Crop-Recommendation-System-Using-Machine-Learning-main\\Crop-Recommendation-System-Using-Machine-Learning-main\\Crop_recommendation.csv")

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.corr()
# Out:
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_10996\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# ...

# %%
fig = plt.figure( figsize= (4,3) , dpi =200)
sns.heatmap(df.corr())
# Out:
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_10996\3708073761.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
fig = plt.figure()
sns.scatterplot(x = "label" , y = "rainfall" , data  = df )
plt.xticks(rotation=90);

# %%
fig = plt.figure()
sns.scatterplot(x = "label" , y = "humidity" , data  = df )
plt.xticks(rotation=90);

# %%
fig = plt.figure()
sns.scatterplot(x = "label" , y = "temperature" , data  = df )
plt.xticks(rotation=90);

# %%
fig = plt.figure()
sns.scatterplot(x = "label" , y = "N" , data  = df )
plt.xticks(rotation=90);

# %%
fig = plt.figure()
sns.scatterplot(x = "label" , y = "P" , data  = df )
plt.xticks(rotation=90);

# %%
fig = plt.figure()
sns.scatterplot(x = "label" , y = "K" , data  = df )
plt.xticks(rotation=90);

# %%
X = df.drop("label" ,axis = 1)
y = df["label"]

# %%
X
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
scaler = StandardScaler()

# %%
scaled_x_train = scaler.fit_transform(X_train)
scaled_x_test = scaler.transform(X_test)

# %%
scaled_x_train
# Out:
# array([[-8.14149162e-01, -8.22608476e-01, -4.17586751e-01, ...,
#         -1.10914730e+00, -1.00850068e+00, -1.14762954e-01],
#        [-5.99794073e-01, -5.52511028e-01, -3.98018725e-01, ...,
#         -8.39738838e-01,  6.40463882e-01, -2.12947619e-01],
#        [ 2.30831896e-01, -2.82413580e-01, -4.95858854e-01, ...,
#         -8.13537964e-02, -9.78595756e-01, -4.59356367e-01],
#        ...,
#        [-1.08209302e+00, -5.22500201e-01, -3.39314648e-01, ...,
#         -9.20572349e-01,  6.00471872e-04, -3.53408620e-02],
#        [-1.08209302e+00,  2.11845263e+00,  3.04595380e+00, ...,
#          3.79045864e-01, -1.48070939e-01, -5.55371242e-01],
#        [-5.19410914e-01,  7.37954558e-01, -5.15426879e-01, ...,
#         -4.34666852e-01,  6.91994073e-01, -8.79579938e-01]])

# %%
scaled_x_test
# Out:
# array([[ 1.32940173, -1.09270592, -0.02622624, ...,  1.05275226,
#         -0.37709414, -1.36794363],
#        [ 1.24901857, -1.36280337,  0.05204587, ...,  0.67567482,
#         -0.28048064, -0.95127435],
#        [ 0.20403751,  0.25778132,  0.01290981, ...,  0.98944543,
#          0.60675059,  0.22630399],
#        ...,
#        [-0.1710839 , -0.1923811 ,  0.13031797, ...,  0.88792123,
#          0.35957596,  0.30716649],
#        [-0.33185021,  0.6779329 ,  0.54124651, ..., -2.58405905,
#          2.16021479, -0.59578774],
#        [ 1.3829905 , -1.12271675,  0.01290981, ...,  0.45138154,
#          0.5732209 , -0.90943832]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# create instances of all models
models = {
    'Logistic Regression': LogisticRegression(),
    'Naive Bayes': GaussianNB(),
    'Support Vector Machine': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Bagging': BaggingClassifier(),
    'AdaBoost': AdaBoostClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'Extra Trees': ExtraTreeClassifier(),
}

# %%
names = []
accuracy = []
for name,model in models.items():
    model.fit(scaled_x_train,y_train)
    y_pred = model.predict(scaled_x_test)
    names.append(name)
    
    print(f"{name}: {accuracy_score(y_test,y_pred)}")
    accuracy.append(accuracy_score(y_test,y_pred))
# Out:
# Logistic Regression: 0.9590909090909091
# Naive Bayes: 0.9939393939393939
# Support Vector Machine: 0.9727272727272728
# K-Nearest Neighbors: 0.9606060606060606
# Decision Tree: 0.9863636363636363
# Random Forest: 0.990909090909091
# Bagging: 0.990909090909091
# AdaBoost: 0.2106060606060606
# Gradient Boosting: 0.9833333333333333
# Extra Trees: 0.9287878787878788

# %%
fig = plt.figure(figsize=(8,4))
plt.plot(names,accuracy)
plt.xticks(rotation=90);

# %%
models.items()
# Out:
# dict_items([('Logistic Regression', LogisticRegression()), ('Naive Bayes', GaussianNB()), ('Support Vector Machine', SVC()), ('K-Nearest Neighbors', KNeighborsClassifier()), ('Decision Tree', DecisionTreeClassifier()), ('Random Forest', RandomForestClassifier()), ('Bagging', BaggingClassifier()), ('AdaBoost', AdaBoostClassifier()), ('Gradient Boosting', GradientBoostingClassifier()), ('Extra Trees', ExtraTreeClassifier())])

# %%
random_forest = RandomForestClassifier()

# %%
random_forest.fit(scaled_x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
ran_y_pred = random_forest.predict(scaled_x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,ran_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       1.00      1.00      1.00        26
#    blackgram       1.00      1.00      1.00        26
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        33
#       coffee       1.00      1.00      1.00        30
#       cotton       1.00      1.00      1.00        28
#       grapes       1.00      1.00      1.00        23
#         jute       0.87      1.00      0.93        34
#  kidneybeans       1.00      1.00      1.00        36
#       lentil       1.00      1.00      1.00        22
#        maize       1.00      1.00      1.00        26
#        mango       1.00      1.00      1.00        32
#    mothbeans       1.00      1.00      1.00        34
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        24
# ...

# %%
accuracy_score(y_test,ran_y_pred)
# Out:
# 0.9924242424242424

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
def predictor(N, P, K, temperature, humidity, ph, rainfall):
    features = np.array([[N,P,K,temperature,humidity,ph,rainfall]])
    transformed_features = scaler.transform(features)
    return random_forest.predict(transformed_features)

# %%
N=9
P=5
K=10
temperature=7.433294     
humidity=47.805077
ph=3.185301
rainfall= 118.733676

predictor(N, P,K, temperature, humidity, ph, rainfall)
# Out:
# C:\Users\SIDDHARTH\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array(['orange'], dtype=object)

# %%
feat = np.array([X.iloc[600]])
transformed_features = scaler.transform(feat)
random_forest.predict(transformed_features)
# Out:
# C:\Users\SIDDHARTH\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array(['mungbean'], dtype=object)

# %%
import pickle
pickle.dump(random_forest,open('model.pkl','wb'))
pickle.dump(scaler,open('standscaler.pkl','wb'))

# %%
df.iloc[600]
# Out:
# N                     19
# P                     55
# K                     20
# temperature    27.433294
# humidity       87.805077
# ph              7.185301
# rainfall       54.733676
# label           mungbean
# Name: 600, dtype: object
